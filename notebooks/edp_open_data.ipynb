# %%
from helper_functions import *
from community_plots import *

# %matplotlib notebook

# %%
data_path = f'../data/edp/' # path relative to notebook, adjust if different for you

dct_scada = load_scada_data(data_path)
dct_logs = load_scada_logs(data_path)
dct_annot = load_annotations(data_path)

dct_community = load_community_annotations(f'../communiy_annotations/edp_community_annotations.csv')
# Out:
# Loading SCADA signals...
# Loading SCADA logs...
# Loading annotations...
# Loading community annotations...
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:121: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(base_path+path_, index_col=dct_unify_colnames['col_time'][i])

# %%
df_data_overview = generate_data_overview(dct_scada, dct_logs)
# Out:
# SCADA DATA OVERVIEW
# +-----------------------------+------------------+------------------+------------------+------------------+
# |                             |       T01        |       T06        |       T07        |       T11        |
# +-----------------------------+------------------+------------------+------------------+------------------+
# |         # Variables         |       84.0       |       84.0       |       84.0       |       84.0       |
# |       First Timestamp       | 2016-01-01 00:00 | 2016-01-01 00:00 | 2016-01-01 00:00 | 2016-01-01 00:00 |
# |       Last Timestamp        | 2017-12-31 23:50 | 2017-12-31 23:50 | 2017-12-31 23:50 | 2017-12-31 23:50 |
# |        # Datapoints         |     104671.0     |     102909.0     |     104727.0     |     104786.0     |
# |     Datapoints missing      |      592.0       |      2354.0      |      536.0       |      477.0       |
# |         Data uptime         |      99.4 %      |      97.8 %      |      99.5 %      |      99.5 %      |
# | Energy Produced Total (MWh) |      9021.0      |      9251.0      |      9546.0      |      9464.0      |
# |      Capacity Factor)       |       0.26       |       0.26       |       0.27       |       0.27       |
# |           FLH (h)           |      2254.0      |      2311.0      |      2385.0      |      2364.0      |
# |        # Log entries        |     76485.0      |     54068.0      |     61014.0      |     61040.0      |
# +-----------------------------+------------------+------------------+------------------+------------------+
# +-----------------------------+
# |         # Variables         |
# |       First Timestamp       |
# |       Last Timestamp        |
# |        # Datapoints         |
# |     Datapoints missing      |
# |         Data uptime         |
# | Energy Produced Total (MWh) |
# |      Capacity Factor)       |
# |           FLH (h)           |
# |        # Log entries        |
# +-----------------------------+

# %%
for trb_id in list(dct_scada.keys()):
    
    # function for overview with power curve, wind rose and data availability chart
    plot_overview_cockpit(data_path, dct_scada, df_data_overview, trb_id, freq_='10T')
    
    plot_summary(trb_id, df_data_overview.loc[trb_id], 
                 dct_annot[trb_id].drop('Turbine_ID',axis=1))
    
    if trb_id in dct_community.keys():
        plot_community_annotations(dct_community[trb_id], dct_scada[trb_id], dct_logs[trb_id])
    else:
        print('=' * 110 +' \n \033[1m \nCommunity Annotations: NONE SO FAR\n \033[1m \n')
# Out:
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T01</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:448: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T01
# ==============================================================================================================
#                              T01
# ---------------------------  ----------------
# # Variables                  84.0
# First Timestamp              2016-01-01 00:00
# Last Timestamp               2017-12-31 23:50
# # Datapoints                 104671.0
# Datapoints missing           592.0
# Data uptime                  99.4 %
# Energy Produced Total (MWh)  9021.0
# Capacity Factor)             0.26
# FLH (h)                      2254.0
# # Log entries                76485.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T01
# ==============================================================================================================
# Timestamp                  Component    Remarks
# -------------------------  -----------  -----------------------
# 2016-07-18 02:10:00+00:00  GEARBOX      Gearbox pump damaged
# 2017-08-11 13:14:00+00:00  TRANSFORMER  Transformer fan damaged
#
#
#
#
#
#
#
# ==============================================================================================================
#  Community Annotations:
# ==============================================================================================================
# ==============================================================================================================
# Community Annotation 1: Amb_WindSpeed_Std with extremely high values
# <img src="data:image/png;base64,..." width="640">
# ==============================================================================================================
# Community Annotation 2: Signal with significantly changed behaviour after start date
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="300">
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T06</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:448: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T06
# ==============================================================================================================
#                              T06
# ---------------------------  ----------------
# # Variables                  84.0
# First Timestamp              2016-01-01 00:00
# Last Timestamp               2017-12-31 23:50
# # Datapoints                 102909.0
# Datapoints missing           2354.0
# Data uptime                  97.8 %
# Energy Produced Total (MWh)  9251.0
# Capacity Factor)             0.26
# FLH (h)                      2311.0
# # Log entries                54068.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T06
# ==============================================================================================================
# Timestamp                  Component        Remarks
# -------------------------  ---------------  ------------------------------------------------------------------
# 2016-04-04 18:53:00+00:00  HYDRAULIC_GROUP  Error in pitch regulation
# 2016-07-11 19:48:00+00:00  GENERATOR        Generator replaced
# 2016-07-24 17:01:00+00:00  GENERATOR        Generator temperature sensor failure
# 2016-09-04 08:08:00+00:00  GENERATOR        High temperature generator error
# 2016-10-02 17:08:00+00:00  GENERATOR        Refrigeration system and temperature sensors in generator replaced
# 2016-10-27 16:26:00+00:00  GENERATOR        Generator replaced
# 2017-08-19 09:47:00+00:00  HYDRAULIC_GROUP  Oil leakage in Hub
# 2017-10-17 08:38:00+00:00  GEARBOX          Gearbox bearings damaged
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T07</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:448: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T07
# ==============================================================================================================
#                              T07
# ---------------------------  ----------------
# # Variables                  84.0
# First Timestamp              2016-01-01 00:00
# Last Timestamp               2017-12-31 23:50
# # Datapoints                 104727.0
# Datapoints missing           536.0
# Data uptime                  99.5 %
# Energy Produced Total (MWh)  9546.0
# Capacity Factor)             0.27
# FLH (h)                      2385.0
# # Log entries                61014.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T07
# ==============================================================================================================
# Timestamp                  Component          Remarks
# -------------------------  -----------------  ----------------------------------------------------------------
# 2016-04-30 12:40:00+00:00  GENERATOR_BEARING  High temperature in generator bearing (replaced sensor)
# 2016-07-10 03:46:00+00:00  TRANSFORMER        High temperature transformer
# 2016-08-23 02:21:00+00:00  TRANSFORMER        High temperature transformer. Transformer refrigeration repaired
# 2017-06-17 11:35:00+00:00  HYDRAULIC_GROUP    Oil leakage in Hub
# 2017-08-20 06:08:00+00:00  GENERATOR_BEARING  Generator bearings damaged
# 2017-08-21 14:47:00+00:00  GENERATOR          Generator damaged
# 2017-10-19 10:11:00+00:00  HYDRAULIC_GROUP    Oil leakage in Hub
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T11</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:448: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T11
# ==============================================================================================================
#                              T11
# ---------------------------  ----------------
# # Variables                  84.0
# First Timestamp              2016-01-01 00:00
# Last Timestamp               2017-12-31 23:50
# # Datapoints                 104786.0
# Datapoints missing           477.0
# Data uptime                  99.5 %
# Energy Produced Total (MWh)  9464.0
# Capacity Factor)             0.27
# FLH (h)                      2364.0
# # Log entries                61040.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T11
# ==============================================================================================================
# Timestamp                  Component        Remarks
# -------------------------  ---------------  ------------------------------------------
# 2016-03-03 19:00:00+00:00  GENERATOR        Electric circuit error in generator
# 2016-10-17 17:44:00+00:00  HYDRAULIC_GROUP  Hydraulic group error in the brake circuit
# 2017-04-26 18:06:00+00:00  HYDRAULIC_GROUP  Hydraulic group error in the brake circuit
# 2017-09-12 15:30:00+00:00  HYDRAULIC_GROUP  Hydraulic group error in the brake circuit
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
