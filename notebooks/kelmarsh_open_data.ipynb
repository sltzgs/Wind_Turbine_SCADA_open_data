# %%
from helper_functions import *
from community_plots import *

# %matplotlib notebook

# %%
data_path = f'../data/kelmarsh/' #download and extract files here

dct_scada = load_scada_data(data_path)
dct_logs = load_scada_logs(data_path)
dct_community = load_community_annotations(f'../communiy_annotations/kelmarsh_community_annotations.csv')
# Out:
# Loading SCADA signals...
# Loading SCADA logs...
# Loading community annotations...

# %%
df_data_overview = generate_data_overview(dct_scada, dct_logs)
# Out:
# SCADA DATA OVERVIEW
# +-----------------------------+------------------+------------------+------------------+------------------+
# |                             |       T01        |       T02        |       T03        |       T04        |
# +-----------------------------+------------------+------------------+------------------+------------------+
# |         # Variables         |      291.0       |      291.0       |      291.0       |      291.0       |
# |       First Timestamp       | 2016-01-23 12:10 | 2016-01-21 14:10 | 2016-01-27 15:50 | 2016-02-04 18:40 |
# |       Last Timestamp        | 2021-06-30 23:50 | 2021-06-30 23:50 | 2021-06-30 23:50 | 2021-06-30 23:50 |
# |        # Datapoints         |     281900.0     |     282021.0     |     280365.0     |     280395.0     |
# |     Datapoints missing      |      4010.0      |      4165.0      |      4947.0      |      3748.0      |
# |         Data uptime         |      98.6 %      |      98.5 %      |      98.3 %      |      98.7 %      |
# | Energy Produced Total (MWh) |     28919.0      |     32474.0      |     27443.0      |     29602.0      |
# |      Capacity Factor)       |       0.3        |       0.34       |       0.29       |       0.31       |
# |           FLH (h)           |      2660.0      |      2984.0      |      2529.0      |      2740.0      |
# |        # Log entries        |     41803.0      |     36838.0      |     54012.0      |     41301.0      |
# +-----------------------------+------------------+------------------+------------------+------------------+
# +-----------------------------+------------------+------------------+
# |                             |       T05        |       T06        |
# +-----------------------------+------------------+------------------+
# |         # Variables         |      291.0       |      291.0       |
# |       First Timestamp       | 2016-01-24 15:10 | 2016-02-05 15:00 |
# |       Last Timestamp        | 2021-06-30 23:50 | 2021-06-30 23:50 |
# |        # Datapoints         |     281064.0     |     279640.0     |
# |     Datapoints missing      |      4684.0      |      4381.0      |
# |         Data uptime         |      98.4 %      |      98.5 %      |
# | Energy Produced Total (MWh) |     27081.0      |     23233.0      |
# |      Capacity Factor)       |       0.28       |       0.25       |
# |           FLH (h)           |      2492.0      |      2151.0      |
# |        # Log entries        |     45179.0      |     63102.0      |
# +-----------------------------+------------------+------------------+

# %%
for trb_id in list(dct_scada.keys()):
    
    # function for overview with power curve, wind rose and data availability chart
    plot_overview_cockpit(data_path, dct_scada, df_data_overview, trb_id, freq_='10T')
    
    plot_summary(trb_id, df_data_overview.loc[trb_id])
        
    if trb_id in dct_community.keys():
        plot_community_annotations(dct_community[trb_id], dct_scada[trb_id], dct_logs[trb_id])
    else:
        print('=' * 110 +' \n \033[1m \nCommunity Annotations: NONE SO FAR\n \033[1m \n')
# Out:
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T01</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T01
# ==============================================================================================================
#                              T01
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-01-23 12:10
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 281900.0
# Datapoints missing           4010.0
# Data uptime                  98.6 %
# Energy Produced Total (MWh)  28919.0
# Capacity Factor)             0.3
# FLH (h)                      2660.0
# # Log entries                41803.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T01
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T02</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T02
# ==============================================================================================================
#                              T02
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-01-21 14:10
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 282021.0
# Datapoints missing           4165.0
# Data uptime                  98.5 %
# Energy Produced Total (MWh)  32474.0
# Capacity Factor)             0.34
# FLH (h)                      2984.0
# # Log entries                36838.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T02
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T03</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T03
# ==============================================================================================================
#                              T03
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-01-27 15:50
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 280365.0
# Datapoints missing           4947.0
# Data uptime                  98.3 %
# Energy Produced Total (MWh)  27443.0
# Capacity Factor)             0.29
# FLH (h)                      2529.0
# # Log entries                54012.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T03
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T04</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T04
# ==============================================================================================================
#                              T04
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-02-04 18:40
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 280395.0
# Datapoints missing           3748.0
# Data uptime                  98.7 %
# Energy Produced Total (MWh)  29602.0
# Capacity Factor)             0.31
# FLH (h)                      2740.0
# # Log entries                41301.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T04
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T05</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T05
# ==============================================================================================================
#                              T05
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-01-24 15:10
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 281064.0
# Datapoints missing           4684.0
# Data uptime                  98.4 %
# Energy Produced Total (MWh)  27081.0
# Capacity Factor)             0.28
# FLH (h)                      2492.0
# # Log entries                45179.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T05
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
#
#
# ==============================================================================================================
# ==============================================================================================================
# <span style="font-size:24px;">Overview-Cockpit Turbine T06</span>
# <img src="data:image/png;base64,..." width="900">
# /home/simon/Documents/0200_Code/0220_git_repros/Wind_Turbine_SCADA_open_data/notebooks/helper_functions.py:449: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ==============================================================================================================
#  KPI Summary T06
# ==============================================================================================================
#                              T06
# ---------------------------  ----------------
# # Variables                  291.0
# First Timestamp              2016-02-05 15:00
# Last Timestamp               2021-06-30 23:50
# # Datapoints                 279640.0
# Datapoints missing           4381.0
# Data uptime                  98.5 %
# Energy Produced Total (MWh)  23233.0
# Capacity Factor)             0.25
# FLH (h)                      2151.0
# # Log entries                63102.0
#
#
#
# ==============================================================================================================
#  Owner Annotations T06
# ==============================================================================================================
# No annotations...
#
#
#
#
#
#
#
# ==============================================================================================================
#
# Community Annotations: NONE SO FAR
